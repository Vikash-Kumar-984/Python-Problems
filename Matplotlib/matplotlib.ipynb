# %%
# Why do we need visualisation? 
# Summarisation of data
#  matplotlib, seaborn, plotly, bokeh
#  Matplotlib:
#  Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. 
#  Matplotlib makes easy things easy and hard things possible

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
#generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50) #Gives normalised value(bell shaped graph)
# Out:
# array([-0.86740091,  1.4923681 ,  0.57543066,  1.79813029, -0.51929611,
#        -0.2678931 , -1.38830695,  0.82205363, -1.3798771 ,  0.69980057,
#         0.85870057,  0.49721616, -0.14556046,  1.2739383 , -1.48977169,
#         1.58796129, -0.08493606,  1.86510418,  0.36345878, -0.39428015,
#        -1.30182093,  1.09129385, -0.78868666, -0.61620738, -0.22960018,
#         1.22945199,  0.56060003, -0.81416577, -0.47611193,  0.46340496,
#        -0.65385358,  1.20055745, -0.66642663,  0.33161552,  0.11190342,
#         0.53978592,  0.10453519, -0.10296725,  0.48922936,  1.02962374,
#        -1.20411252,  0.64614374, -1.12424316, -0.28883846, -0.14476973,
#         2.81930512, -0.62559964, -1.64481738, -0.25096944, -0.03105475])

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11  1.595261
# 2024-07-12  0.897656
# 2024-07-13  0.432007
# 2024-07-14 -0.436834
# 2024-07-15 -0.453036
# ...              ...
# 2027-04-02  0.326476
# 2027-04-03 -0.335198
# 2027-04-04  1.663580
# 2027-04-05  0.453525
# 2027-04-06 -0.234283
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8)) #summary>> most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.88667581, 0.44005236, 0.7803999 , 0.37021862, 0.67541629,
#        0.47476809, 0.45330166, 0.18225574, 0.50818219, 0.86250839,
#        0.00861153, 0.66442729, 0.82429182, 0.72441208, 0.49801696,
#        0.40451029, 0.08264543, 0.81235464, 0.49929654, 0.2370195 ,
#        0.76523491, 0.22356726, 0.55943321, 0.66803789, 0.96914345,
#        0.04026855, 0.75554749, 0.6663313 , 0.82642875, 0.81317427,
#        0.89109013, 0.570975  , 0.45386563, 0.91856273, 0.60735455,
#        0.8091964 , 0.55983028, 0.11016317, 0.06761811, 0.20637289,
#        0.25983291, 0.24728437, 0.78093035, 0.61810331, 0.50907677,
#        0.39178383, 0.00437994, 0.21432856, 0.28271941, 0.57302398])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.62117749, 0.75700476, 0.47324043, 0.74447053, 0.61853386,
#        0.59701147, 0.53749321, 0.03092654, 0.95323225, 0.91354146,
#        0.82879372, 0.59339399, 0.71087383, 0.34195629, 0.54870426,
#        0.27485725, 0.09562384, 0.63711242, 0.13351687, 0.03362606,
#        0.44720796, 0.33271056, 0.38887052, 0.34729656, 0.74382685,
#        0.25047061, 0.94801952, 0.10682654, 0.34644073, 0.77812713,
#        0.60532852, 0.12509159, 0.76244977, 0.56346989, 0.19760321,
#        0.28523085, 0.04274449, 0.35025799, 0.58552991, 0.24457141,
#        0.7195854 , 0.03711332, 0.27240828, 0.31618633, 0.22823692,
#        0.63173857, 0.33841858, 0.88524405, 0.09169167, 0.81006051])

# %%
#scatter plot:
# A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane. 
# Each point represents the value of one variable corresponding to the value of the other variable
plt.scatter(x, y)

# %%
#line plot
#whenever you want to depict the relation between two variables in the form of trend
#mostly in x axis the date - time column is there
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show() #It will remove the metadata

# %%
plt.plot(x, y, color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y1 as tata motors")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y2 as tata power")

plt.title("Multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure() #initialising a page to make plot
plt.subplot(1, 2, 1) #1 Row, 2 Column, Select 1
plt.plot(x, np.sin(x))

plt.subplot(1, 2, 2) #1 Row, 2 Column, Select 2
plt.plot(x, np.cos(x))

plt.show()
