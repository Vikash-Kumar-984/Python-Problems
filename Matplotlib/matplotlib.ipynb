# %%
# Why do we need visualisation? 
#  Summarisation of data
#  matplotlib, seaborn, plotly, bokeh
#  Matplotlib:
#  Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. 
#  Matplotlib makes easy things easy and hard things possible

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
#Generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50) #Gives normalised value(bell shaped graph)
# Out:
# array([-1.63786995,  0.31758122,  0.28510799, -1.6719605 ,  0.96095718,
#         1.66692189, -1.11631654, -1.04765523, -2.00944726,  0.00388172,
#         0.91608216, -2.24846091, -0.8029402 , -0.71935148,  0.14714033,
#        -0.69870706,  1.86467626,  0.52452847, -2.69094578,  0.79144917,
#         0.79703035, -0.69589473, -0.65253598, -0.52422498,  0.58550513,
#        -0.45795382, -0.03408945,  0.5345045 , -0.2128774 ,  0.46888601,
#        -0.48436205, -0.24954582, -0.32058926, -0.8665101 , -0.64146557,
#        -0.7774138 ,  0.09497031, -0.34354317, -0.68618229, -0.27424956,
#        -2.27845032,  0.5548847 ,  0.15822097, -0.24713457,  0.12707534,
#         0.87263432,  1.15302065, -1.17749184,  0.77446011,  0.93918764])

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11 -0.433811
# 2024-07-12 -1.069135
# 2024-07-13 -1.569938
# 2024-07-14  0.184425
# 2024-07-15 -0.050983
# ...              ...
# 2027-04-02  1.170547
# 2027-04-03  0.618087
# 2027-04-04  0.273820
# 2027-04-05 -0.651278
# 2027-04-06 -0.092514
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8)) #Summary (Observations): Most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.13088784, 0.64847051, 0.19967395, 0.35767007, 0.45944792,
#        0.08661837, 0.98795453, 0.37850537, 0.77127055, 0.04294203,
#        0.73785688, 0.26728514, 0.40436029, 0.18428587, 0.01812723,
#        0.32414021, 0.06806698, 0.87067119, 0.69496544, 0.40772982,
#        0.37255345, 0.0549243 , 0.46525274, 0.63345824, 0.01743922,
#        0.87694448, 0.94700787, 0.2836925 , 0.36635711, 0.33149148,
#        0.42022487, 0.19087521, 0.74031188, 0.63409437, 0.25063913,
#        0.53986522, 0.91132997, 0.50284126, 0.66366811, 0.83741012,
#        0.82296801, 0.04194611, 0.43135063, 0.38579873, 0.40175049,
#        0.87982868, 0.56808514, 0.77349948, 0.18147627, 0.76703045])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.45611517, 0.02040986, 0.58316327, 0.3550227 , 0.50114262,
#        0.55782822, 0.59149717, 0.34215838, 0.28589321, 0.68558849,
#        0.01838968, 0.00354756, 0.05924811, 0.53098987, 0.67920683,
#        0.72777826, 0.0102113 , 0.08947624, 0.14671477, 0.00987243,
#        0.97949218, 0.08978488, 0.22798428, 0.11683061, 0.61720864,
#        0.54446374, 0.32491411, 0.68555351, 0.16265103, 0.82397707,
#        0.7856815 , 0.82004244, 0.99301366, 0.88012954, 0.64155159,
#        0.36223665, 0.0570064 , 0.79085764, 0.12956848, 0.86827834,
#        0.89654301, 0.2451036 , 0.56158158, 0.79144012, 0.78980449,
#        0.65744751, 0.57581832, 0.09974311, 0.85156728, 0.09369532])

# %%
# Scatter Plot:
# A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane. 
# Each point represents the value of one variable corresponding to the value of the other variable
plt.scatter(x, y)

# %%
#Line Plot
#Whenever we want to depict the relation between two variables in the form of trend
#Mostly in x axis the date - time column is there
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.show() #It will remove the metadata

# %%
plt.plot(x, y, color = "red")
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4)
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("Line Chart to understand the syntax")
plt.xlabel("Day Interval as x points")
plt.ylabel("Price as y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y1 as tata motors")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y2 as tata power")

plt.title("Multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("Stock Price")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure() #Initialising a page to make plot
plt.subplot(1, 2, 1) #1 Row, 2 Column, Select 1
plt.plot(x, np.sin(x))

plt.subplot(1, 2, 2) #1 Row, 2 Column, Select 2
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() #Initialising a page to make plot
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue')

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5) #To limit the value between range
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal') # It will help to adjust according to sapce and leave no blank space
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid() # It will add graph at background
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#Histogram: Continuous Numerical Data

data = np.random.randn(1000) #by default 10 bins (intervals) are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, color = 'r', bins = 20) 
plt.show()

# %%
#Stacked Histogram: Two histograms together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([-0.12164548,  2.19938555, -0.57685165, ..., -0.52735823,
#        -0.12758428, -0.66059195], shape=(5000,))

# %%
data2
# Out:
# array([ 4.87840716,  3.76144776,  2.48283735, ...,  2.55343875,
#        -0.31374725,  0.50102521], shape=(5000,))

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#Scatterplot: To understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)
x
# Out:
# array([0.57462552, 0.89603828, 0.9749622 , 0.94156056, 0.32162721,
#        0.89312777, 0.73911209, 0.98657486, 0.21336087, 0.01462157,
#        0.23943565, 0.84055419, 0.68450252, 0.45522118, 0.63970809,
#        0.6798646 , 0.45912041, 0.26321799, 0.34034778, 0.25097089,
#        0.04573982, 0.98788669, 0.85464704, 0.50077319, 0.32586838,
#        0.59219568, 0.71853329, 0.82176496, 0.38445988, 0.12207094,
#        0.00339197, 0.6752538 , 0.28508145, 0.51419132, 0.60917026,
#        0.5184085 , 0.75596381, 0.27196254, 0.09943796, 0.0184203 ,
#        0.4920593 , 0.24952659, 0.38220023, 0.57062328, 0.40439515,
#        0.33733168, 0.73172653, 0.90617988, 0.59605505, 0.19137167])

# %%
y
# Out:
# array([0.02748298, 0.2687295 , 0.91460431, 0.60035852, 0.46268402,
#        0.64771392, 0.25907326, 0.24579419, 0.74320847, 0.65220392,
#        0.47402995, 0.55351925, 0.90838935, 0.96254055, 0.79518862,
#        0.76123291, 0.34799935, 0.8274099 , 0.6907631 , 0.62136207,
#        0.66984816, 0.60301567, 0.48004288, 0.47244691, 0.05882316,
#        0.94400469, 0.20995329, 0.25113423, 0.55991284, 0.09899474,
#        0.76769669, 0.34585161, 0.55110842, 0.10049239, 0.65035687,
#        0.79148549, 0.62944521, 0.5491945 , 0.63913404, 0.86601762,
#        0.31737858, 0.91098891, 0.281863  , 0.94790304, 0.54956803,
#        0.18052021, 0.53840642, 0.22795159, 0.548604  , 0.9583833 ])

# %%
plt.scatter(x, y, c = 'r', marker = "X")

# %%
#Bar Plot: To see the districution of categorical variables

x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.bar(x, y, color = 'r') #Vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.barh(x, y, color = 'b') #Horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
# Pie Chart: To understand the percent distribution of data
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
#Focus on one segment

explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode)
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode, shadow = True) #Shadow
plt.title("Pie chart")
plt.show()

# %%
#3d plot: 3 Dimension plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv") # Import data from local computer/folder
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x = data['Age'], y=data["Balance"])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color = 'red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color = 'yellow')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplot: To check the distribution of data and outliers(extreme/abnormal values)

data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
#Violinplot: To identify outliers

plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x73a852c13230>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x73a852d0c3b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x73a852ce0b90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x73a852ce0a70>}

# %%
# Area Plot: Variables changed over time

# An area plot, also called a stacked area plot, is a type of data visualization that shows how
# various quantitative factors have changed over time while highlighting how they all work together to form the whole. 
# It's particularly good for illustrating how elements of a whole change over time or along a continuous dimension.
# A layered representation of the data is produced in an area plot by layering many variables on top of one another. 
# The cumulative influence of all levels provides insight into the overall trend. Each layer represents a separate category or variable. 
# To distinguish between categories, the space beneath each layer is frequently colored.

years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

plt.stackplot(years, category1, category2, category3, labels = ["category1", "category2", "category3",],
             colors = ["skyblue","lightgreen", "orange"])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
